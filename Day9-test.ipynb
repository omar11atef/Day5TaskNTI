# %% [markdown]
# # Day/9 :

# %%
import numpy as np
import pandas as pd
file = r'C:\Users\ZBook\Desktop\juypter\ClusteringHSS.csv'

# %%
data = pd.read_csv(file)
data.head()
# Out:
#    ID Gender_Code Region  Income  Spending
# 0   1      Female  Rural    20.0      15.0
# 1   2        Male  Rural     5.0      12.0
# 2   3      Female  Urban    28.0      18.0
# 3   4        Male  Urban    40.0      10.0
# 4   5        Male  Urban    42.0       9.0

# %%
print(data.isnull().sum())
print(data.dtypes)
print(data.shape)
print(data.head())
# Out:
# ID             0
# Gender_Code    6
# Region         6
# Income         6
# Spending       5
# dtype: int64
# ID               int64
# Gender_Code     object
# Region          object
# Income         float64
# Spending       float64
# dtype: object
# (1113, 5)
#    ID Gender_Code Region  Income  Spending
# 0   1      Female  Rural    20.0      15.0
# 1   2        Male  Rural     5.0      12.0
# 2   3      Female  Urban    28.0      18.0
# 3   4        Male  Urban    40.0      10.0
# 4   5        Male  Urban    42.0       9.0

# %%
data = data.dropna()

# %%
print(data.isnull())
# Out:
#          ID  Gender_Code  Region  Income  Spending
# 0     False        False   False   False     False
# 1     False        False   False   False     False
# 2     False        False   False   False     False
# 3     False        False   False   False     False
# 4     False        False   False   False     False
# ...     ...          ...     ...     ...       ...
# 1108  False        False   False   False     False
# 1109  False        False   False   False     False
# 1110  False        False   False   False     False
# 1111  False        False   False   False     False
# 1112  False        False   False   False     False
#
# [1113 rows x 5 columns]

# %%
print(data.isnull().sum())
# Out:
# ID             0
# Gender_Code    6
# Region         6
# Income         6
# Spending       5
# dtype: int64

# %%
# Fill missing Gender.Code values with 'Unknown'
data['Gender_Code'] = data['Gender_Code'].fillna('Unknown')

# %%
# Fill missing Region values with 'Unknown'
data['Region'] = data['Region'].fillna('Unknown')

# %%
# Fill missing Income values with the mode (most frequent value)

data['Income'] = data['Income'].fillna(data['Income'].mode()[0])

# %%
# Import required library
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder objects for each categorical column
le_gender = LabelEncoder()
le_region = LabelEncoder()
# Encode Gender_Code column
data['Gender_Code'] = le_gender.fit_transform(data['Gender_Code'])
# Encode Region column
data['Region'] = le_region.fit_transform(data['Region'])

# %%
data.dtypes
# Out:
# ID               int64
# Gender_Code      int64
# Region           int64
# Income         float64
# Spending       float64
# dtype: object

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')  # or 'median', 'most_frequent'
data_imputed = imputer.fit_transform(data)

kmeans.fit(data_imputed)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(df, kmeans.labels_)
print(f"Silhouette Score :", silhouette_avg)

# %%
inertia = []
k_range = range(1, 11)
for k in k_range:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(df)
    inertia.append(km.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(k_range, inertia, marker='o', linestyle='-')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(df)
silhouette_avg = silhouette_score(df, kmeans.labels_)
print(f"Silhouette Score :", silhouette_avg)

# %%
for cluster_id in sorted(df_with_clusters['cluster'].unique()):
    indices = df_with_clusters[df_with_clusters['cluster'] == cluster_id].index.tolist()
    indices_str = ', '.join(str(idx) for idx in indices)
    print(f"Cluster {cluster_id} = row {indices_str}")

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

linked = linkage(df, method='ward')

plt.figure(figsize=(10, 6))
dendrogram(linked, labels=df.index.tolist(), leaf_rotation=90)
plt.title('Dendrogram with Custom Index Labels')
plt.xlabel('Sample')
plt.ylabel('Distance')
plt.tight_layout()
plt.show()

# %%
km = KMeans(n_clusters=5, random_state=32)
km.fit(df)
sil_score = silhouette_score(df, km.labels_)
print('Silhouette Score:', sil_score)
