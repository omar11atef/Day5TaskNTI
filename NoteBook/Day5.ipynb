# %%
import numpy as np
import pandas as pd

# %%
url = "C:\\Users\\Omar_Atif\\Desktop\\jupyter python\\gym_membership.csv"

# %%
data = pd.read_csv(url)
data.head()
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
# 3   4    Male  1980-04-12   44        Premium               3
# 4   5    Male  1980-09-10   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                         NaN
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1000 non-null   int64
#  1   gender                 1000 non-null   object
#  2   birthday               1000 non-null   object
#  3   Age                    1000 non-null   int64
#  4   abonoment_type         1000 non-null   object
#  5   visit_per_week         1000 non-null   int64
#  6   days_per_week          1000 non-null   object
#  7   attend_group_lesson    1000 non-null   bool
#  8   fav_group_lesson       1000 non-null   object
#  9   avg_time_check_in      1000 non-null   object
#  10  avg_time_check_out     1000 non-null   object
#  11  avg_time_in_gym        1000 non-null   int64
#  12  drink_abo              1000 non-null   bool
#  13  fav_drink              496 non-null    object
# ...

# %%
data.isna().sum()
# Out:
# id                         0
# gender                     0
# birthday                   0
# Age                        0
# abonoment_type             0
# visit_per_week             0
# days_per_week              0
# attend_group_lesson        0
# fav_group_lesson         497
# avg_time_check_in          0
# avg_time_check_out         0
# avg_time_in_gym            0
# drink_abo                  0
# fav_drink                504
# personal_training          0
# name_personal_trainer    482
# uses_sauna                 0
# dtype: int64

# %%
data['fav_group_lesson'] = data['fav_group_lesson'].fillna("Not Found")
data.head()
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
# 3   4    Male  1980-04-12   44        Premium               3
# 4   5    Male  1980-09-10   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                   Not Found
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                   Not Found
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
data.isnull().mean()*100
# Out:
# id                        0.0
# gender                    0.0
# birthday                  0.0
# Age                       0.0
# abonoment_type            0.0
# visit_per_week            0.0
# days_per_week             0.0
# attend_group_lesson       0.0
# fav_group_lesson          0.0
# avg_time_check_in         0.0
# avg_time_check_out        0.0
# avg_time_in_gym           0.0
# drink_abo                 0.0
# fav_drink                50.4
# personal_training         0.0
# name_personal_trainer    48.2
# uses_sauna                0.0
# dtype: float64

# %%
data.describe(include='object')
# Out:
#         gender    birthday abonoment_type days_per_week fav_group_lesson  \
# count     1000        1000           1000          1000             1000
# unique       2         974              2           115              254
# top     Female  2001-07-09       Standard           Sun        Not Found
# freq       503           2            507            37              497
#
#        avg_time_check_in avg_time_check_out          fav_drink  \
# count               1000               1000                496
# unique               556                572                 36
# top             17:57:00           14:08:00  coconut_pineapple
# freq                   6                  6                 53
#
#        name_personal_trainer
# count                    518
# unique                     4
# top                  Chantal
# freq                     153

# %%
type(data['fav_drink'])
# Out:
# pandas.core.series.Series

# %%
data['fav_drink'] = data['fav_drink'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1000 non-null   int64
#  1   gender                 1000 non-null   object
#  2   birthday               1000 non-null   object
#  3   Age                    1000 non-null   int64
#  4   abonoment_type         1000 non-null   object
#  5   visit_per_week         1000 non-null   int64
#  6   days_per_week          1000 non-null   object
#  7   attend_group_lesson    1000 non-null   bool
#  8   fav_group_lesson       1000 non-null   object
#  9   avg_time_check_in      1000 non-null   object
#  10  avg_time_check_out     1000 non-null   object
#  11  avg_time_in_gym        1000 non-null   int64
#  12  drink_abo              1000 non-null   bool
#  13  fav_drink              496 non-null    category
# ...

# %%
data['fav_drink'].value_counts()
# Out:
# fav_drink
# coconut_pineapple                   53
# passion_fruit                       52
# lemon                               47
# berry_boost                         42
# orange                              40
# black_currant                       39
# orange, black_currant               12
# passion_fruit, orange               12
# berry_boost, orange                 12
# orange, berry_boost                 11
# lemon, black_currant                11
# coconut_pineapple, black_currant    10
# black_currant, coconut_pineapple     9
# berry_boost, coconut_pineapple       9
# berry_boost, black_currant           9
# passion_fruit, coconut_pineapple     9
# coconut_pineapple, orange            9
# passion_fruit, berry_boost           8
# coconut_pineapple, lemon             8
# coconut_pineapple, passion_fruit     8
# orange, coconut_pineapple            8
# lemon, berry_boost                   7
# lemon, passion_fruit                 7
# lemon, orange                        7
# ...

# %%
data[data['Age'] > 30]
# Out:
#       id  gender    birthday  Age abonoment_type  visit_per_week  \
# 1      2  Female  1977-09-18   47       Standard               3
# 2      3    Male  1983-03-30   41        Premium               1
# 3      4    Male  1980-04-12   44        Premium               3
# 4      5    Male  1980-09-10   44       Standard               2
# 8      9    Male  1978-07-28   46        Premium               3
# ..   ...     ...         ...  ...            ...             ...
# 991  992    Male  1991-08-12   33        Premium               3
# 992  993  Female  1985-10-02   39       Standard               5
# 994  995  Female  1988-03-23   36       Standard               2
# 995  996  Female  1984-09-22   40       Standard               3
# 997  998    Male  1984-10-05   40       Standard               2
#
#                days_per_week  attend_group_lesson      fav_group_lesson  \
# 1              Mon, Sat, Wed                False             Not Found
# ...

# %%
data['visit_per_week'].agg(['mean', 'min', 'max'])
# Out:
# mean    2.682
# min     1.000
# max     5.000
# Name: visit_per_week, dtype: float64

# %%
data.groupby('abonoment_type')['visit_per_week'].max()
# Out:
# abonoment_type
# Premium     5
# Standard    5
# Name: visit_per_week, dtype: int64

# %%
# Get Top 5 Trains in that dep..on Avg Time in Gym
top_5_trainers = (
    data.groupby('name_personal_trainer')['avg_time_in_gym']
    .mean()                              # get average per trainer
    .sort_values(ascending=False)       # sort by average descending
    .head(5)                             # get top 5
)
top_5_trainers = top_5_trainers.reset_index()
top_5_trainers.columns = ['name_personal_trainer', 'average_time_in_gym']
print(top_5_trainers)
# Out:
#   name_personal_trainer  average_time_in_gym
# 0               Jeffrey           109.882883
# 1                 Hanna           108.798246
# 2                  Mike           105.914286
# 3               Chantal           101.575163

# %%
sns.boxplot(x='fav_drink', y='avg_time_in_gym', data=data)
plt.title('Avg Time in Gym by Favorite Drink')
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x='Age', y='avg_time_in_gym', data=data)
plt.title('Age vs Avg Time in Gym')
plt.show()

# أو تحليل إحصائي
age_avg_time = data.groupby('Age')['avg_time_in_gym'].mean()
print(age_avg_time)
# Out:
# Age
# 12    109.235294
# 13     81.375000
# 14    115.472222
# 15    122.611111
# 16     97.166667
# 17    116.923077
# 18    111.730769
# 19    105.965517
# 20    115.428571
# 21     97.913043
# 22     99.535714
# 23    104.678571
# 24    107.606061
# 25     93.150000
# 26    104.970588
# 27    113.437500
# 28    112.333333
# 29     97.787879
# 30    105.555556
# 31    112.736842
# 32    114.476190
# 33    110.172414
# 34    100.320000
# 35    113.148148
# 36    107.972973
# 37    102.500000
# 38     99.750000
# 39     87.972222
# 40    105.920000
# 41    103.000000
# 42    118.875000
# 43    113.454545
# 44    103.409091
# 45    117.866667
# 46    109.578947
# 47     91.777778
# 48    104.960000
# 49     80.096774
# Name: avg_time_in_gym, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['avg_time_check_in'], data['avg_time_check_out'], color = 'red', marker='x')
plt.show()

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
# Select only numeric columns
numeric_data = data.select_dtypes(include=['number'])
scatter_matrix(numeric_data, figsize=(10, 10))
plt.show()

# %%
plt.boxplot(data['Age'])
plt.show()

# %%
data.head()
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
# 3   4    Male  1980-04-12   44        Premium               3
# 4   5    Male  1980-09-10   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                   Not Found
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                   Not Found
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='visit_per_week', data=data, order=sorted(data['visit_per_week'].unique()))
plt.title('Number of Visits per Week')
plt.xlabel('Visits per Week')
plt.ylabel('Number of Members')
plt.show()

# %%
#
import seaborn as sns
import matplotlib.pyplot as plt

sns.relplot(
    x="days_per_week",
    y="avg_time_in_gym",
    data=data,
    kind="scatter",
    size="visit_per_week",
    hue="uses_sauna_str",
    palette={"yes": "black", "no": "red"},
    sizes=(20, 200)  # controls min and max marker size
)

plt.title("Avg Time in Gym vs Days per Week with Sauna Usage")
plt.show()

# %%
# best Time go gym : 
plt.figure(figsize=(10,5))
sns.histplot(data['avg_time_check_in'], bins=20, kde=True)
plt.title('Check-in Time Distribution')
plt.xlabel('Average Check-in Time')
plt.ylabel('Number of Members')
plt.show()
